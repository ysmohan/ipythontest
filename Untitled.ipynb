# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
parag="My name is Yamni. I like nltk. I like python. I make tutorials"

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(parag)
# Out:
# ['My name is Yamni.', 'I like nltk.', 'I like python.', 'I make tutorials']

# %%
myarr=sent_tokenize(parag)

# %%
print (myarr)
# Out:
# ['My name is Yamni.', 'I like nltk.', 'I like python.', 'I make tutorials']

# %%
import nltk.data

# %%
tokenizer=nltk.data.load('tokenizers/punkt/english.pickle')

# %%
print (parag)
# Out:
# My name is Yamni. I like nltk. I like python. I make tutorials

# %%
arr_2=tokenizer.tokenize(parag)

# %%
print (arr_2[0])
# Out:
# My name is Yamni.

# %%
tokenizer.tokenize(arr_2[0])
# Out:
# ['My name is Yamni.']

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(arr_2[0])
# Out:
# ['My', 'name', 'is', 'Yamni', '.']

# %%
f=open('hamlet.txt')
raw=f.read()

# %%
from nltk.tokenize import sent_tokenize

# %%
datdat=sent_tokenize(raw)

# %%
from nltk.tokenize import regexp_tokenize

# %%
sent1="I can't do this. I won't do that."

# %%
regexp_tokenize(sent1, "[\w']+")
# Out:
# ['I', "can't", 'do', 'this', 'I', "won't", 'do', 'that']

# %%
print (datdat[0])
# Out:
# 	HAMLET
#
#
# 	DRAMATIS PERSONAE
#
#
# CLAUDIUS	king of Denmark.

# %%
sent1=datdat[3]

# %%
print(sent1)
# Out:
# (LORD POLONIUS:)
#
# HORATIO	friend to Hamlet.

# %%
regexp_tokenize(sent1, "[\w]+")
# Out:
# ['LORD', 'POLONIUS', 'HORATIO', 'friend', 'to', 'Hamlet']

# %%
from nltk.tokenize import RegexpTokenizer

# %%
tokenizer=RegexpTokenizer("[\w']+")

# %%
tokenizer.tokenize(sent1)
# Out:
# ['LORD', 'POLONIUS', 'HORATIO', 'friend', 'to', 'Hamlet']

# %%
tokenizer.tokenize(datdat[2])
# Out:
# ['POLONIUS', 'lord', 'chamberlain']

# %%
from nltk.corpus import stopwords

# %%
ensw=stopwords.words('english')

# %%
print(raw)
# Out:
# 	HAMLET
#
#
# 	DRAMATIS PERSONAE
#
#
# CLAUDIUS	king of Denmark. (KING CLAUDIUS:)
#
# HAMLET	son to the late, and nephew to the present king.
#
# POLONIUS	lord chamberlain. (LORD POLONIUS:)
#
# HORATIO	friend to Hamlet.
#
# LAERTES	son to Polonius.
#
# LUCIANUS	nephew to the king.
#
#
# VOLTIMAND	|
# 	|
# CORNELIUS	|
# 	|
# ROSENCRANTZ	|  courtiers.
# 	|
# GUILDENSTERN	|
# 	|
# OSRIC	|
#
#
# 	A Gentleman, (Gentlemen:)
#
# 	A Priest. (First Priest:)
#
#
# MARCELLUS	|
# 	|  officers.
# BERNARDO	|
#
#
# FRANCISCO	a soldier.
#
# REYNALDO	servant to Polonius.
# 	Players.
# 	(First Player:)
# 	(Player King:)
# 	(Player Queen:)
#
# 	Two Clowns, grave-diggers.
# 	(First Clown:)
# 	(Second Clown:)
#
# FORTINBRAS	prince of Norway. (PRINCE FORTINBRAS:)
#
# 	A Captain.
#
# 	English Ambassadors. (First Ambassador:)
#
# GERTRUDE	queen of Denmark, and mother to Hamlet.
# 	(QUEEN GERTRUDE:)
#
# OPHELIA	daughter to Polonius.
#
# 	Lords, Ladies, Officers, Soldiers, Sailors, Messengers,
# ...

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# Out:
# 152793

# %%
# Out:
# "\tHAMLET\n\n\n\tDRAMATIS PERSONAE\n\n\nCLAUDIUS\tking of Denmark. (KING CLAUDIUS:)\n\nHAMLET\tson to the late, and nephew to the present king.\n\nPOLONIUS\tlord chamberlain. (LORD POLONIUS:)\n\nHORATIO\tfriend to Hamlet.\n\nLAERTES\tson to Polonius.\n\nLUCIANUS\tnephew to the king.\n\n\nVOLTIMAND\t|\n\t|\nCORNELIUS\t|\n\t|\nROSENCRANTZ\t|  courtiers.\n\t|\nGUILDENSTERN\t|\n\t|\nOSRIC\t|\n\n\n\tA Gentleman, (Gentlemen:)\n\n\tA Priest. (First Priest:)\n\n\nMARCELLUS\t|\n\t|  officers.\nBERNARDO\t|\n\n\nFRANCISCO\ta soldier.\n\nREYNALDO\tservant to Polonius.\n\tPlayers.\n\t(First Player:)\n\t(Player King:)\n\t(Player Queen:)\n\n\tTwo Clowns, grave-diggers.\n\t(First Clown:)\n\t(Second Clown:)\n\nFORTINBRAS\tprince of Norway. (PRINCE FORTINBRAS:)\n\n\tA Captain.\n\n\tEnglish Ambassadors. (First Ambassador:)\n\nGERTRUDE\tqueen of Denmark, and mother to Hamlet.\n\t(QUEEN GERTRUDE:)\n\nOPHELIA\tdaughter to Polonius.\n\n\tLords, Ladies, Officers, Soldiers, Sailors, Messengers,\n\tand other 
# ...
